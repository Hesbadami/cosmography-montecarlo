# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
q
# Out:
# array([-0.68983583, -0.68884805, -0.68786028, -0.6868725 , -0.68588472,
#        -0.68489694, -0.68390916, -0.68292139, -0.68193361, -0.68094583,
#        -0.67995805, -0.67897027, -0.67798249, -0.67699472, -0.67600694,
#        -0.67501916, -0.67403138, -0.6730436 , -0.67205583, -0.67106805,
#        -0.67008027, -0.66909249, -0.66810471, -0.66711693, -0.66612916,
#        -0.66514138, -0.6641536 , -0.66316582, -0.66217804, -0.66119026,
#        -0.66020249, -0.65921471, -0.65822693, -0.65723915, -0.65625137,
#        -0.6552636 , -0.65427582, -0.65328804, -0.65230026, -0.65131248,
#        -0.6503247 , -0.64933693, -0.64834915, -0.64736137, -0.64637359,
#        -0.64538581, -0.64439803, -0.64341026, -0.64242248, -0.6414347 ,
#        -0.64044692, -0.63945914, -0.63847137, -0.63748359, -0.63649581,
#        -0.63550803, -0.63452025, -0.63353247, -0.6325447 , -0.63155692,
#        -0.63056914, -0.62958136, -0.62859358, -0.62760581, -0.62661803,
# ...

# %%
d4d = np.genfromtxt('4d.txt')
q4 = d4d[:, 0]
j4 = d4d[:, 1]
s4 = d4d[:, 2]
l4 = d4d[:, 3]

# %%
q0 = data[:, 2]
j0 = data[:, 3]
s0 = data[:, 4]
l0 = data[:, 5]

# %%
plt.scatter(q, j)

# %%
plt.scatter(q4, j4)

# %%
len(q4)
# Out:
# 1929

# %%
plt.scatter(q0, j0)
